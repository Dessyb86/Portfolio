# %%
#importing libraries

import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import xarray as xr
import cftime
import cartopy
from dateutil.relativedelta import relativedelta
import matplotlib as mpl
from matplotlib import colors
from scipy.interpolate import griddata
from scipy.stats import ks_2samp

import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from matplotlib.patches import Path, PathPatch
import cartopy.feature as cfeature
import cartopy.crs as ccrs

import math
from sklearn.metrics import mean_squared_error

# %%
years = np.arange(1989,2021,1)
years
# Out:
# array([1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
J_E1 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E1.*-01-*.nc")
J_E2 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E2.*-01-*.nc")
J_E3 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E3.*-01-*.nc")
J_E4 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E4.*-01-*.nc")
J_E5 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E5.*-01-*.nc")
J_E6 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E6.*-01-*.nc")
J_E7 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E7.*-01-*.nc")
J_E8 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E8.*-01-*.nc")
J_E9 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.JanIC.E9.*-01-*.nc")
F_E1 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E1.*-02-*.nc")
F_E2 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E2.*-02-*.nc")
F_E3 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E3.*-02-*.nc")
F_E4 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E4.*-02-*.nc")
F_E5 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E5.*-02-*.nc")
F_E6 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E6.*-02-*.nc")
F_E7 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E7.*-02-*.nc")
F_E8 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E8.*-02-*.nc")
F_E9 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.FebIC.E9.*-02-*.nc")
M_E1 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E1.*-03-*.nc")
M_E2 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E2.*-03-*.nc")
M_E3 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E3.*-03-*.nc")
M_E4 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E4.*-03-*.nc")
M_E5 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E5.*-03-*.nc")
M_E6 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E6.*-03-*.nc")
M_E7 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E7.*-03-*.nc")
M_E8 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E8.*-03-*.nc")
M_E9 = xr.open_mfdataset("/Volumes/NMME_Daily/CCSM4.DailyT2mPrec.MarIC.E9.*-03-*.nc")

# %%
E1_merge = xr.merge([J_E1, F_E1, M_E1], join="outer")
E2_merge = xr.merge([J_E2, F_E2, M_E2], join="outer")
E3_merge = xr.merge([J_E3, F_E3, M_E3], join="outer")
E4_merge = xr.merge([J_E4, F_E4, M_E4], join="outer")
E5_merge = xr.merge([J_E5, F_E5, M_E5], join="outer")
E6_merge = xr.merge([J_E6, F_E6, M_E6], join="outer")
E7_merge = xr.merge([J_E7, F_E7, M_E7], join="outer")
E8_merge = xr.merge([J_E8, F_E8, M_E8], join="outer")
E9_merge = xr.merge([J_E9, F_E9, M_E9], join="outer")

# %%
E1_merge = E1_merge.sel(time=E1_merge.time.dt.year.isin(years))
E2_merge = E2_merge.sel(time=E2_merge.time.dt.year.isin(years))
E3_merge = E3_merge.sel(time=E3_merge.time.dt.year.isin(years))
E4_merge = E4_merge.sel(time=E4_merge.time.dt.year.isin(years))
E5_merge = E5_merge.sel(time=E5_merge.time.dt.year.isin(years))
E6_merge = E6_merge.sel(time=E6_merge.time.dt.year.isin(years))
E7_merge = E7_merge.sel(time=E7_merge.time.dt.year.isin(years))
E8_merge = E8_merge.sel(time=E8_merge.time.dt.year.isin(years))
E9_merge = E9_merge.sel(time=E9_merge.time.dt.year.isin(years))

# %%
min_lon = 0
max_lon = 360

min_lat = 0
max_lat = 90

mask_lon = (E1_merge.lon >= min_lon) & (E1_merge.lon <= max_lon)
mask_lat = (E1_merge.lat >= min_lat) & (E1_merge.lat <= max_lat)

NH_E1 = E1_merge.where(mask_lon & mask_lat, drop=True)
NH_E2 = E2_merge.where(mask_lon & mask_lat, drop=True)
NH_E3 = E3_merge.where(mask_lon & mask_lat, drop=True)
NH_E4 = E4_merge.where(mask_lon & mask_lat, drop=True)
NH_E5 = E5_merge.where(mask_lon & mask_lat, drop=True)
NH_E6 = E6_merge.where(mask_lon & mask_lat, drop=True)
NH_E7 = E7_merge.where(mask_lon & mask_lat, drop=True)
NH_E8 = E8_merge.where(mask_lon & mask_lat, drop=True)
NH_E9 = E9_merge.where(mask_lon & mask_lat, drop=True)

# %%
NH_E1.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E1.nc")
NH_E2.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E2.nc")
NH_E3.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E3.nc")
NH_E4.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E4.nc")
NH_E5.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E5.nc")
NH_E6.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E6.nc")
NH_E7.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E7.nc")
NH_E8.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E8.nc")
NH_E9.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/NH_E9.nc")

# %%
J_E1_max = J_E1.groupby('time.year').max('time')
J_E2_max = J_E2.groupby('time.year').max('time')
J_E3_max = J_E3.groupby('time.year').max('time')
J_E4_max = J_E4.groupby('time.year').max('time')
J_E5_max = J_E5.groupby('time.year').max('time')
J_E6_max = J_E6.groupby('time.year').max('time')
J_E7_max = J_E7.groupby('time.year').max('time')
J_E8_max = J_E8.groupby('time.year').max('time')
J_E9_max = J_E9.groupby('time.year').max('time')
F_E1_max = F_E1.groupby('time.year').max('time')
F_E2_max = F_E2.groupby('time.year').max('time')
F_E3_max = F_E3.groupby('time.year').max('time')
F_E4_max = F_E4.groupby('time.year').max('time')
F_E5_max = F_E5.groupby('time.year').max('time')
F_E6_max = F_E6.groupby('time.year').max('time')
F_E7_max = F_E7.groupby('time.year').max('time')
F_E8_max = F_E8.groupby('time.year').max('time')
F_E9_max = F_E9.groupby('time.year').max('time')
M_E1_max = M_E1.groupby('time.year').max('time')
M_E2_max = M_E2.groupby('time.year').max('time')
M_E3_max = M_E3.groupby('time.year').max('time')
M_E4_max = M_E4.groupby('time.year').max('time')
M_E5_max = M_E5.groupby('time.year').max('time')
M_E6_max = M_E6.groupby('time.year').max('time')
M_E7_max = M_E7.groupby('time.year').max('time')
M_E8_max = M_E8.groupby('time.year').max('time')
M_E9_max = M_E9.groupby('time.year').max('time')

# %%
J_E1_max = J_E1_max.sel(year=slice(1989, 2020))
J_E2_max = J_E2_max.sel(year=slice(1989, 2020))
J_E3_max = J_E3_max.sel(year=slice(1989, 2020))
J_E4_max = J_E4_max.sel(year=slice(1989, 2020))
J_E5_max = J_E5_max.sel(year=slice(1989, 2020))
J_E6_max = J_E6_max.sel(year=slice(1989, 2020))
J_E7_max = J_E7_max.sel(year=slice(1989, 2020))
J_E8_max = J_E8_max.sel(year=slice(1989, 2020))
J_E9_max = J_E9_max.sel(year=slice(1989, 2020))
F_E1_max = J_E1_max.sel(year=slice(1989, 2020))
F_E2_max = J_E2_max.sel(year=slice(1989, 2020))
F_E3_max = J_E3_max.sel(year=slice(1989, 2020))
F_E4_max = J_E4_max.sel(year=slice(1989, 2020))
F_E5_max = J_E5_max.sel(year=slice(1989, 2020))
F_E6_max = J_E6_max.sel(year=slice(1989, 2020))
F_E7_max = J_E7_max.sel(year=slice(1989, 2020))
F_E8_max = J_E8_max.sel(year=slice(1989, 2020))
F_E9_max = J_E9_max.sel(year=slice(1989, 2020))
M_E1_max = M_E1_max.sel(year=slice(1989, 2020))
M_E2_max = M_E2_max.sel(year=slice(1989, 2020))
M_E3_max = M_E3_max.sel(year=slice(1989, 2020))
M_E4_max = M_E4_max.sel(year=slice(1989, 2020))
M_E5_max = M_E5_max.sel(year=slice(1989, 2020))
M_E6_max = M_E6_max.sel(year=slice(1989, 2020))
M_E7_max = M_E7_max.sel(year=slice(1989, 2020))
M_E8_max = M_E8_max.sel(year=slice(1989, 2020))
M_E9_max = M_E9_max.sel(year=slice(1989, 2020))

# %%
years = np.arange(1989,2021,1)

J_times = []
F_times = []
M_times = []

    
for i in range(len(years)):
    
    J_times.append(cftime.DatetimeNoLeap(years[i], 1, 1))
    F_times.append(cftime.DatetimeNoLeap(years[i], 2, 1))
    M_times.append(cftime.DatetimeNoLeap(years[i], 3, 1))

# %%
J_E1_max = J_E1_max.assign_coords(year = J_times)
J_E2_max = J_E2_max.assign_coords(year = J_times)
J_E3_max = J_E3_max.assign_coords(year = J_times)
J_E4_max = J_E4_max.assign_coords(year = J_times)
J_E5_max = J_E5_max.assign_coords(year = J_times)
J_E6_max = J_E6_max.assign_coords(year = J_times)
J_E7_max = J_E7_max.assign_coords(year = J_times)
J_E8_max = J_E8_max.assign_coords(year = J_times)
J_E9_max = J_E9_max.assign_coords(year = J_times)
F_E1_max = F_E1_max.assign_coords(year = F_times)
F_E2_max = F_E2_max.assign_coords(year = F_times)
F_E3_max = F_E3_max.assign_coords(year = F_times)
F_E4_max = F_E4_max.assign_coords(year = F_times)
F_E5_max = F_E5_max.assign_coords(year = F_times)
F_E6_max = F_E6_max.assign_coords(year = F_times)
F_E7_max = F_E7_max.assign_coords(year = F_times)
F_E8_max = F_E8_max.assign_coords(year = F_times)
F_E9_max = F_E9_max.assign_coords(year = F_times)
M_E1_max = M_E1_max.assign_coords(year = M_times)
M_E2_max = M_E2_max.assign_coords(year = M_times)
M_E3_max = M_E3_max.assign_coords(year = M_times)
M_E4_max = M_E4_max.assign_coords(year = M_times)
M_E5_max = M_E5_max.assign_coords(year = M_times)
M_E6_max = M_E6_max.assign_coords(year = M_times)
M_E7_max = M_E7_max.assign_coords(year = M_times)
M_E8_max = M_E8_max.assign_coords(year = M_times)
M_E9_max = M_E9_max.assign_coords(year = M_times)

# %%
J_E1_max = J_E2_max.rename({'year': 'time'})
J_E2_max = J_E2_max.rename({'year': 'time'})
J_E3_max = J_E3_max.rename({'year': 'time'})
J_E4_max = J_E4_max.rename({'year': 'time'})
J_E5_max = J_E5_max.rename({'year': 'time'})
J_E6_max = J_E6_max.rename({'year': 'time'})
J_E7_max = J_E7_max.rename({'year': 'time'})
J_E8_max = J_E8_max.rename({'year': 'time'})
J_E9_max = J_E9_max.rename({'year': 'time'})
F_E1_max = F_E1_max.rename({'year': 'time'})
F_E2_max = F_E2_max.rename({'year': 'time'})
F_E3_max = F_E3_max.rename({'year': 'time'})
F_E4_max = F_E4_max.rename({'year': 'time'})
F_E5_max = F_E5_max.rename({'year': 'time'})
F_E6_max = F_E6_max.rename({'year': 'time'})
F_E7_max = F_E7_max.rename({'year': 'time'})
F_E8_max = F_E8_max.rename({'year': 'time'})
F_E9_max = F_E9_max.rename({'year': 'time'})
M_E1_max = M_E1_max.rename({'year': 'time'})
M_E2_max = M_E2_max.rename({'year': 'time'})
M_E3_max = M_E3_max.rename({'year': 'time'})
M_E4_max = M_E4_max.rename({'year': 'time'})
M_E5_max = M_E5_max.rename({'year': 'time'})
M_E6_max = M_E6_max.rename({'year': 'time'})
M_E7_max = M_E7_max.rename({'year': 'time'})
M_E8_max = M_E8_max.rename({'year': 'time'})
M_E9_max = M_E9_max.rename({'year': 'time'})

# %%
M_E1_max
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 32, lat: 192, lon: 288)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) object 1989-03-01 00:00:00 ... 2020-03-01 00:00:00
# Data variables:
#     PRECT    (time, lat, lon) float32 dask.array<chunksize=(1, 192, 288), meta=np.ndarray>
#     TREFHT   (time, lat, lon) float32 dask.array<chunksize=(1, 192, 288), meta=np.ndarray>

# %%
E1 = xr.merge([J_E1_max, F_E1_max, M_E1_max], join="outer")
E2 = xr.merge([J_E2_max, F_E2_max, M_E2_max], join="outer")
E3 = xr.merge([J_E3_max, F_E3_max, M_E3_max], join="outer")
E4 = xr.merge([J_E4_max, F_E4_max, M_E4_max], join="outer")
E5 = xr.merge([J_E5_max, F_E5_max, M_E5_max], join="outer")
E6 = xr.merge([J_E6_max, F_E6_max, M_E6_max], join="outer")
E7 = xr.merge([J_E7_max, F_E7_max, M_E7_max], join="outer")
E8 = xr.merge([J_E8_max, F_E8_max, M_E8_max], join="outer")
E9 = xr.merge([J_E9_max, F_E9_max, M_E9_max], join="outer")

# %%
min_lon = 0
max_lon = 360

min_lat = 0
max_lat = 90

mask_lon = (E1.lon >= min_lon) & (E1.lon <= max_lon)
mask_lat = (E1.lat >= min_lat) & (E1.lat <= max_lat)

cropped_E1 = E1.where(mask_lon & mask_lat, drop=True)
cropped_E2 = E2.where(mask_lon & mask_lat, drop=True)
cropped_E3 = E3.where(mask_lon & mask_lat, drop=True)
cropped_E4 = E4.where(mask_lon & mask_lat, drop=True)
cropped_E5 = E5.where(mask_lon & mask_lat, drop=True)
cropped_E6 = E6.where(mask_lon & mask_lat, drop=True)
cropped_E7 = E7.where(mask_lon & mask_lat, drop=True)
cropped_E8 = E8.where(mask_lon & mask_lat, drop=True)
cropped_E9 = E9.where(mask_lon & mask_lat, drop=True)

# %%
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 96, lat: 96, lon: 288)
# Coordinates:
#   * time     (time) object 1989-01-01 00:00:00 ... 2020-03-01 00:00:00
#   * lat      (lat) float64 0.4712 1.414 2.356 3.298 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     PRECT    (time, lat, lon) float32 dask.array<chunksize=(4, 96, 288), meta=np.ndarray>
#     TREFHT   (time, lat, lon) float32 dask.array<chunksize=(4, 96, 288), meta=np.ndarray>

# %%
cropped_E1.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E1.nc4")
cropped_E2.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E2.nc4")
cropped_E3.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E3.nc4")
cropped_E4.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E4.nc4")
cropped_E5.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E5.nc4")
cropped_E6.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E6.nc4")
cropped_E7.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E7.nc4")
cropped_E8.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E8.nc4")
cropped_E9.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/cropped_E9.nc4")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [207], in <module>
# ----> 1 cropped_E1
#
# NameError: name 'cropped_E1' is not defined

# %%
E1.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E1.nc4")
E2.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E2.nc4")
E3.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E3.nc4")
E4.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E4.nc4")
E5.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E5.nc4")
E6.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E6.nc4")
E7.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E7.nc4")
E8.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E8.nc4")
E9.to_netcdf("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E9.nc4")

# %%
full_narr = xr.open_mfdataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/acpcp_data/daily/subset/acpcp.*.nc")
# Out:
# /opt/miniconda3/envs/MPO624/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'acpcp' has multiple fill values {9.96921e+36, -9.96921e+36}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /opt/miniconda3/envs/MPO624/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'acpcp' has multiple fill values {9.96921e+36, -9.96921e+36}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /opt/miniconda3/envs/MPO624/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'acpcp' has multiple fill values {9.96921e+36, -9.96921e+36}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /opt/miniconda3/envs/MPO624/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'acpcp' has multiple fill values {9.96921e+36, -9.96921e+36}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# ...

# %%
full_narr.acpcp
# Out:
# <xarray.DataArray 'acpcp' (time: 11688, y: 277, x: 349)>
# dask.array<concatenate, shape=(11688, 277, 349), dtype=float32, chunksize=(366, 277, 349), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1989-01-01 1989-01-02 ... 2020-12-31
#     lat      (y, x) float32 dask.array<chunksize=(277, 349), meta=np.ndarray>
#     lon      (y, x) float32 dask.array<chunksize=(277, 349), meta=np.ndarray>
#   * y        (y) float32 0.0 3.246e+04 6.493e+04 ... 8.927e+06 8.96e+06
#   * x        (x) float32 0.0 3.246e+04 6.493e+04 ... 1.126e+07 1.13e+07
# Attributes:
#     GRIB_id:        63
#     GRIB_name:      ACPCP
#     grid_mapping:   Lambert_Conformal
#     level_desc:     Surface
#     standard_name:  convective_precipitation_amount
#     units:          kg/m^2
#     var_desc:       convective precipitation accumulation
#     dataset:        NARR Daily Sums
#     long_name:      Daily accumulated convective precipitation at Surface
# ...

# %%
narr_winter = full_narr.sel(time=full_narr.time.dt.month.isin([1,2,3]))

# %%
narr_acpcp = narr_winter.acpcp

# %%
narr_acpcp = narr_acpcp.drop([np.datetime64('1992-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('1996-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('2000-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('2004-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('2008-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('2012-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('2016-02-29')], dim='time')
narr_acpcp = narr_acpcp.drop([np.datetime64('2020-02-29')], dim='time')

# %%
#setting lat and lon arrays

nlat = narr_acpcp.lat.values
nlon = narr_acpcp.lon.values
ntime = narr_acpcp.time.values

elat = NH_E1.lat.values
elon = NH_E1.lon.values - 180
etime = NH_E1.time.values

# %%
print(len(ntime),len(etime))
# Out:
# 2880 2880

# %%
X_new_t, Y_new_t = np.meshgrid(elon, elat)

X_new = X_new_t.flatten()
Y_new = Y_new_t.flatten()

x = nlon.flatten()
y = nlat.flatten()

# %%
len(NH_E1.PRECT.lat.values)
# Out:
# 164

# %%
acpcp_data = []

for i in range(len(ntime)):
    
    Z = (np.array(narr_acpcp[i,:,:].values)).flatten()
    
    Z_new = griddata((x, y), Z, (X_new, Y_new), method='nearest')
    
    acpcp_data.append(np.array(Z_new.reshape(164,288)))

# %%
data_narr = np.array(acpcp_data)
data_E1 = np.array(NH_E1.PRECT.values)
data_E2 = np.array(NH_E2.PRECT.values)
data_E3 = np.array(NH_E3.PRECT.values)
data_E4 = np.array(NH_E4.PRECT.values)
data_E5 = np.array(NH_E5.PRECT.values)
data_E6 = np.array(NH_E6.PRECT.values)
data_E7 = np.array(NH_E7.PRECT.values)
data_E8 = np.array(NH_E8.PRECT.values)
data_E9 = np.array(NH_E9.PRECT.values)

# %%
E1_rmse = np.zeros((164,288),dtype = 'float')
E2_rmse = np.zeros((164,288),dtype = 'float')
E3_rmse = np.zeros((164,288),dtype = 'float')
E4_rmse = np.zeros((164,288),dtype = 'float')
E5_rmse = np.zeros((164,288),dtype = 'float')
E6_rmse = np.zeros((164,288),dtype = 'float')
E7_rmse = np.zeros((164,288),dtype = 'float')
E8_rmse = np.zeros((164,288),dtype = 'float')
E9_rmse = np.zeros((164,288),dtype = 'float')
E1_pvalue = np.zeros((164,288),dtype = 'float')
E2_pvalue = np.zeros((164,288),dtype = 'float')
E3_pvalue = np.zeros((164,288),dtype = 'float')
E4_pvalue = np.zeros((164,288),dtype = 'float')
E5_pvalue = np.zeros((164,288),dtype = 'float')
E6_pvalue = np.zeros((164,288),dtype = 'float')
E7_pvalue = np.zeros((164,288),dtype = 'float')
E8_pvalue = np.zeros((164,288),dtype = 'float')
E9_pvalue = np.zeros((164,288),dtype = 'float')

# %%
actual = [0, 1, 2, 6, 3]  
predicted = [0.2, 2.3, 4.5, 0.5, 1.1] 

rmse = math.sqrt(mean_squared_error(actual, predicted))

ks = ks_2samp(actual,predicted)
  
print(rmse,ks[1])
# Out:
# 2.8927495570823267 1.0

# %%
for i in range(164):
    for j in range(288):
        
        df = pd.DataFrame({'nr':data_narr[:,i,j],'e1':data_E1[:,i,j],'e2':data_E2[:,i,j],'e3':data_E3[:,i,j],'e4':data_E4[:,i,j],'e5':data_E5[:,i,j],'e6':data_E6[:,i,j],'e7':data_E7[:,i,j],'e8':data_E8[:,i,j],'e9':data_E9[:,i,j]})
        
        df = df.dropna()
        
        if df.shape[0] == 0:
            
            E1_rmse[i,j] = np.nan
            E1_pvalue[i,j] = np.nan
            E2_rmse[i,j] = np.nan
            E2_pvalue[i,j] = np.nan
            E3_rmse[i,j] = np.nan
            E3_pvalue[i,j] = np.nan
            E4_rmse[i,j] = np.nan
            E4_pvalue[i,j] = np.nan
            E5_rmse[i,j] = np.nan
            E5_pvalue[i,j] = np.nan
            E6_rmse[i,j] = np.nan
            E6_pvalue[i,j] = np.nan
            E7_rmse[i,j] = np.nan
            E7_pvalue[i,j] = np.nan
            E8_rmse[i,j] = np.nan
            E8_pvalue[i,j] = np.nan
            E9_rmse[i,j] = np.nan
            E9_pvalue[i,j] = np.nan
            
        
        else:
            
            E1_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e1']))
            E1_pvalue[i,j] = (ks_2samp(df['nr'],df['e1']))[1]
            E2_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e2']))
            E2_pvalue[i,j] = (ks_2samp(df['nr'],df['e2']))[1]
            E3_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e3']))
            E3_pvalue[i,j] = (ks_2samp(df['nr'],df['e3']))[1]
            E4_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e4']))
            E4_pvalue[i,j] = (ks_2samp(df['nr'],df['e4']))[1]
            E5_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e5']))
            E5_pvalue[i,j] = (ks_2samp(df['nr'],df['e5']))[1]
            E6_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e6']))
            E6_pvalue[i,j] = (ks_2samp(df['nr'],df['e6']))[1]
            E7_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e7']))
            E7_pvalue[i,j] = (ks_2samp(df['nr'],df['e7']))[1]
            E8_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e8']))
            E8_pvalue[i,j] = (ks_2samp(df['nr'],df['e8']))[1]
            E9_rmse[i,j] = math.sqrt(mean_squared_error(df['nr'], df['e9']))
            E9_pvalue[i,j] = (ks_2samp(df['nr'],df['e9']))[1]

# %% [markdown]
# E1_rmme.shape

# %%
E1_rmse_df = pd.DataFrame(E1_rmse)
E2_rmse_df = pd.DataFrame(E2_rmse)
E3_rmse_df = pd.DataFrame(E3_rmse)
E4_rmse_df = pd.DataFrame(E4_rmse)
E5_rmse_df = pd.DataFrame(E5_rmse)
E6_rmse_df = pd.DataFrame(E6_rmse)
E7_rmse_df = pd.DataFrame(E7_rmse)
E8_rmse_df = pd.DataFrame(E8_rmse)
E9_rmse_df = pd.DataFrame(E9_rmse)
E1_pvalue_df = pd.DataFrame(E1_pvalue)
E2_pvalue_df = pd.DataFrame(E2_pvalue)
E3_pvalue_df = pd.DataFrame(E3_pvalue)
E4_pvalue_df = pd.DataFrame(E4_pvalue)
E5_pvalue_df = pd.DataFrame(E5_pvalue)
E6_pvalue_df = pd.DataFrame(E6_pvalue)
E7_pvalue_df = pd.DataFrame(E7_pvalue)
E8_pvalue_df = pd.DataFrame(E8_pvalue)
E9_pvalue_df = pd.DataFrame(E9_pvalue)

# %%
 
# save the dataframe as a csv file
E1_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E1_rmse.csv", index=False)
E2_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E2_rmse.csv", index=False)
E3_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E3_rmse.csv", index=False)
E4_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E4_rmse.csv", index=False)
E5_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E5_rmse.csv", index=False)
E6_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E6_rmse.csv", index=False)
E7_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E7_rmse.csv", index=False)
E8_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E8_rmse.csv", index=False)
E9_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E9_rmse.csv", index=False)
E1_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E1_pvalue.csv", index=False)
E2_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E2_pvalue.csv", index=False)
E3_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E3_pvalue.csv", index=False)
E4_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E4_pvalue.csv", index=False)
E5_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E5_pvalue.csv", index=False)
E6_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E6_pvalue.csv", index=False)
E7_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E7_pvalue.csv", index=False)
E8_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E8_pvalue.csv", index=False)
E9_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E9_pvalue.csv", index=False)

# %%
narr_max_acpcp = xr.open_dataset('/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/narr.nc4')

# %%
narr_max_acpcp
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 96, y: 277, x: 349, nbnds: 2)
# Coordinates:
#   * time               (time) datetime64[ns] 1989-01-01 ... 2020-03-01
#     lat                (y, x) float32 1.0 1.104 1.208 ... 46.93 46.64 46.35
#     lon                (y, x) float32 -145.5 -145.3 -145.1 ... -2.644 -2.57
#   * y                  (y) float32 0.0 3.246e+04 ... 8.927e+06 8.96e+06
#   * x                  (x) float32 0.0 3.246e+04 ... 1.126e+07 1.13e+07
# Dimensions without coordinates: nbnds
# Data variables:
#     Lambert_Conformal  (time) float64 ...
#     acpcp              (time, y, x) float32 ...
#     time_bnds          (time, nbnds) float64 ...

# %%
cropped_E1
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 96, lat: 96, lon: 288)
# Coordinates:
#   * time     (time) object 1989-01-01 00:00:00 ... 2020-03-01 00:00:00
#   * lat      (lat) float64 0.4712 1.414 2.356 3.298 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     PRECT    (time, lat, lon) float32 9.883 7.714 8.396 ... 1.705 1.705 1.705
#     TREFHT   (time, lat, lon) float32 300.3 300.1 300.4 ... 261.7 261.7 261.8

# %%
#setting lat and lon arrays

max_nlat = narr_max_acpcp.lat.values
max_nlon = narr_max_acpcp.lon.values
max_ntime = narr_max_acpcp.time.values

elat = cropped_E1.lat.values
elon = cropped_E1.lon.values - 180
etime = cropped_E1.time.values

X_new_t, Y_new_t = np.meshgrid(elon, elat)

X_new = X_new_t.flatten()
Y_new = Y_new_t.flatten()

x = max_nlon.flatten()
y = max_nlat.flatten()

acpcp_max_data = []

for i in range(len(max_ntime)):
    
    Z = (np.array(narr_max_acpcp.acpcp[i,:,:].values)).flatten()
    
    Z_new = griddata((x, y), Z, (X_new, Y_new), method='nearest')
    
    acpcp_max_data.append(np.array(Z_new.reshape(96,288)))

# %%
E1 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E1.nc4")
E2 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E2.nc4")
E3 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E3.nc4")
E4 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E4.nc4")
E5 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E5.nc4")
E6 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E6.nc4")
E7 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E7.nc4")
E8 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E8.nc4")
E9 = xr.open_dataset("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E9.nc4")

# %%
np.array(cropped_E1.lon.values)-180
# Out:
# array([-180.  , -178.75, -177.5 , -176.25, -175.  , -173.75, -172.5 ,
#        -171.25, -170.  , -168.75, -167.5 , -166.25, -165.  , -163.75,
#        -162.5 , -161.25, -160.  , -158.75, -157.5 , -156.25, -155.  ,
#        -153.75, -152.5 , -151.25, -150.  , -148.75, -147.5 , -146.25,
#        -145.  , -143.75, -142.5 , -141.25, -140.  , -138.75, -137.5 ,
#        -136.25, -135.  , -133.75, -132.5 , -131.25, -130.  , -128.75,
#        -127.5 , -126.25, -125.  , -123.75, -122.5 , -121.25, -120.  ,
#        -118.75, -117.5 , -116.25, -115.  , -113.75, -112.5 , -111.25,
#        -110.  , -108.75, -107.5 , -106.25, -105.  , -103.75, -102.5 ,
#        -101.25, -100.  ,  -98.75,  -97.5 ,  -96.25,  -95.  ,  -93.75,
#         -92.5 ,  -91.25,  -90.  ,  -88.75,  -87.5 ,  -86.25,  -85.  ,
#         -83.75,  -82.5 ,  -81.25,  -80.  ,  -78.75,  -77.5 ,  -76.25,
#         -75.  ,  -73.75,  -72.5 ,  -71.25,  -70.  ,  -68.75,  -67.5 ,
# ...

# %%
min_lon = 0
max_lon = 360

min_lat = 0
max_lat = 90

mask_lon = (E1.lon >= min_lon) & (E1.lon <= max_lon)
mask_lat = (E1.lat >= min_lat) & (E1.lat <= max_lat)

cropped_E1 = E1.where(mask_lon & mask_lat, drop=True)
cropped_E2 = E2.where(mask_lon & mask_lat, drop=True)
cropped_E3 = E3.where(mask_lon & mask_lat, drop=True)
cropped_E4 = E4.where(mask_lon & mask_lat, drop=True)
cropped_E5 = E5.where(mask_lon & mask_lat, drop=True)
cropped_E6 = E6.where(mask_lon & mask_lat, drop=True)
cropped_E7 = E7.where(mask_lon & mask_lat, drop=True)
cropped_E8 = E8.where(mask_lon & mask_lat, drop=True)
cropped_E9 = E9.where(mask_lon & mask_lat, drop=True)

# %%
data_narr = np.array(acpcp_max_data)
data_E1 = np.array(cropped_E1.PRECT.values)
data_E2 = np.array(cropped_E2.PRECT.values)
data_E3 = np.array(cropped_E3.PRECT.values)
data_E4 = np.array(cropped_E4.PRECT.values)
data_E5 = np.array(cropped_E5.PRECT.values)
data_E6 = np.array(cropped_E6.PRECT.values)
data_E7 = np.array(cropped_E7.PRECT.values)
data_E8 = np.array(cropped_E8.PRECT.values)
data_E9 = np.array(cropped_E9.PRECT.values)

# %%
data_E1.shape
# Out:
# (96, 96, 288)

# %%
data_narr.shape
# Out:
# (96, 96, 288)

# %%
E1_max_rmse = np.zeros((96,288),dtype = 'float')
E2_max_rmse = np.zeros((96,288),dtype = 'float')
E3_max_rmse = np.zeros((96,288),dtype = 'float')
E4_max_rmse = np.zeros((96,288),dtype = 'float')
E5_max_rmse = np.zeros((96,288),dtype = 'float')
E6_max_rmse = np.zeros((96,288),dtype = 'float')
E7_max_rmse = np.zeros((96,288),dtype = 'float')
E8_max_rmse = np.zeros((96,288),dtype = 'float')
E9_max_rmse = np.zeros((96,288),dtype = 'float')
E1_max_pvalue = np.zeros((96,288),dtype = 'float')
E2_max_pvalue = np.zeros((96,288),dtype = 'float')
E3_max_pvalue = np.zeros((96,288),dtype = 'float')
E4_max_pvalue = np.zeros((96,288),dtype = 'float')
E5_max_pvalue = np.zeros((96,288),dtype = 'float')
E6_max_pvalue = np.zeros((96,288),dtype = 'float')
E7_max_pvalue = np.zeros((96,288),dtype = 'float')
E8_max_pvalue = np.zeros((96,288),dtype = 'float')
E9_max_pvalue = np.zeros((96,288),dtype = 'float')

# %%
for i in range(96):
    for j in range(288):
        
        df_max = pd.DataFrame({'nr':data_narr[:,i,j],'e1':data_E1[:,i,j],'e2':data_E2[:,i,j],'e3':data_E3[:,i,j],'e4':data_E4[:,i,j],'e5':data_E5[:,i,j],'e6':data_E6[:,i,j],'e7':data_E7[:,i,j],'e8':data_E8[:,i,j],'e9':data_E9[:,i,j]})
        
        df_max = df_max.dropna()
        
        if df_max.shape[0] == 0:
            
            E1_max_rmse[i,j] = np.nan
            E1_max_pvalue[i,j] = np.nan
            E2_max_rmse[i,j] = np.nan
            E2_max_pvalue[i,j] = np.nan
            E3_max_rmse[i,j] = np.nan
            E3_max_pvalue[i,j] = np.nan
            E4_max_rmse[i,j] = np.nan
            E4_max_pvalue[i,j] = np.nan
            E5_max_rmse[i,j] = np.nan
            E5_max_pvalue[i,j] = np.nan
            E6_max_rmse[i,j] = np.nan
            E6_max_pvalue[i,j] = np.nan
            E7_max_rmse[i,j] = np.nan
            E7_max_pvalue[i,j] = np.nan
            E8_max_rmse[i,j] = np.nan
            E8_max_pvalue[i,j] = np.nan
            E9_max_rmse[i,j] = np.nan
            E9_max_pvalue[i,j] = np.nan
            
        
        else:
            
            E1_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e1']))
            E1_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e1']))[1]
            E2_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e2']))
            E2_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e2']))[1]
            E3_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e3']))
            E3_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e3']))[1]
            E4_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e4']))
            E4_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e4']))[1]
            E5_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e5']))
            E5_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e5']))[1]
            E6_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e6']))
            E6_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e6']))[1]
            E7_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e7']))
            E7_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e7']))[1]
            E8_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e8']))
            E8_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e8']))[1]
            E9_max_rmse[i,j] = math.sqrt(mean_squared_error(df_max['nr'], df_max['e9']))
            E9_max_pvalue[i,j] = (ks_2samp(df_max['nr'],df_max['e9']))[1]

# %%
E1_max_rmse_df = pd.DataFrame(E1_max_rmse)
E2_max_rmse_df = pd.DataFrame(E2_max_rmse)
E3_max_rmse_df = pd.DataFrame(E3_max_rmse)
E4_max_rmse_df = pd.DataFrame(E4_max_rmse)
E5_max_rmse_df = pd.DataFrame(E5_max_rmse)
E6_max_rmse_df = pd.DataFrame(E6_max_rmse)
E7_max_rmse_df = pd.DataFrame(E7_max_rmse)
E8_max_rmse_df = pd.DataFrame(E8_max_rmse)
E9_max_rmse_df = pd.DataFrame(E9_max_rmse)
E1_max_pvalue_df = pd.DataFrame(E1_max_pvalue)
E2_max_pvalue_df = pd.DataFrame(E2_max_pvalue)
E3_max_pvalue_df = pd.DataFrame(E3_max_pvalue)
E4_max_pvalue_df = pd.DataFrame(E4_max_pvalue)
E5_max_pvalue_df = pd.DataFrame(E5_max_pvalue)
E6_max_pvalue_df = pd.DataFrame(E6_max_pvalue)
E7_max_pvalue_df = pd.DataFrame(E7_max_pvalue)
E8_max_pvalue_df = pd.DataFrame(E8_max_pvalue)
E9_max_pvalue_df = pd.DataFrame(E9_max_pvalue)

# %%
# save the dataframe as a csv file
E1_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E1_max_rmse.csv", index=False)
E2_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E2_max_rmse.csv", index=False)
E3_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E3_max_rmse.csv", index=False)
E4_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E4_max_rmse.csv", index=False)
E5_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E5_max_rmse.csv", index=False)
E6_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E6_max_rmse.csv", index=False)
E7_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E7_max_rmse.csv", index=False)
E8_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E8_max_rmse.csv", index=False)
E9_max_rmse_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E9_max_rmse.csv", index=False)
E1_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E1_max_pvalue.csv", index=False)
E2_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E2_max_pvalue.csv", index=False)
E3_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E3_max_pvalue.csv", index=False)
E4_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E4_max_pvalue.csv", index=False)
E5_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E5_max_pvalue.csv", index=False)
E6_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E6_max_pvalue.csv", index=False)
E7_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E7_max_pvalue.csv", index=False)
E8_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E8_max_pvalue.csv", index=False)
E9_max_pvalue_df.to_csv("/Users/dessyb/Library/CloudStorage/Box-Box/Patrick_MS/data/climate_model_data/E9_max_pvalue.csv", index=False)
